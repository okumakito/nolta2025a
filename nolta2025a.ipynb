# %% [markdown]
# # nolta2025a
#
# This notebook shows how to run the source codes used in the following work:
#
# * Makito Oku: "Designing efficient interventions for pre-disease states using control theory", submitted to NOLTA.
#
# All the source files are in the scripts directory. Figures 9 to 14 are omitted from this notebook because they require real data.

# %%
# Initial settings
# %cd /content/
# !rm -rf nolta2025a
# !git clone https://github.com/okumakito/nolta2025a
# !pip install POT
# %cd ./nolta2025a/scripts
# %run -i functions.py
# Out:
# /content
# Cloning into 'nolta2025a'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 59 (delta 10), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (59/59), 170.43 KiB | 2.40 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# ...
# /content/nolta2025a/scripts

# %%
# %run -i plot_fig02.py
plt.show()

# %%
# %run -i plot_fig03.py
plt.show()

# %%
# %run -i plot_fig04.py
plt.show()
# Out:
# target elements: 10 (2.5 %)
# i= 9, j= 8, h=0.90, F=0.00223
# target elements: 13 (3.2 %)
# i= 9, j= 8, h=0.90, F=0.28936
# i=11, j=10, h=0.80, F=0.32615
# target elements: 24 (6.0 %)
# i= 9, j= 8, h=0.90, F=0.51905
# i= 7, j= 6, h=0.90, F=0.77795
# i=11, j=10, h=0.80, F=0.80421

# %%
# %run -i plot_fig05.py
plt.show()
# Out:
# target elements: 60 (0.6 %)
# i=55, j=45, h=0.90, F=-0.01086
# i=55, j=44, h=0.90, F=0.03275
# i=54, j=44, h=0.90, F=0.07025
# i=45, j=44, h=0.90, F=0.10375
# i=65, j=55, h=0.90, F=0.11896
# i=56, j=55, h=0.90, F=0.13839
# i=66, j=55, h=0.90, F=0.16542
# i=46, j=45, h=0.80, F=0.17650
# i=56, j=45, h=0.80, F=0.18921
# i=56, j=44, h=0.80, F=0.19631
# i=54, j=43, h=0.80, F=0.20260
# i=53, j=43, h=0.80, F=0.20742
# i=34, j=33, h=0.80, F=0.21107
# i=44, j=33, h=0.80, F=0.21582
# i=35, j=33, h=0.80, F=0.21991
# i=43, j=33, h=0.80, F=0.22277
# i=45, j=44, h=0.80, F=0.22345
# i=66, j=55, h=0.80, F=0.22372
# 0.10473990096781664

# %%
# %run -i plot_fig06.py
plt.show()
# Out:
# target elements: 50 (2.0 %)
# i= 0, j=13, h=0.90, F=0.00576
# i=19, j=41, h=0.90, F=0.02799
# i=48, j=13, h=0.90, F=0.04677
# i=38, j=13, h=0.90, F=0.07524
# i=10, j=17, h=0.90, F=0.09276
# i=38, j=19, h=0.90, F=0.10876
# i=13, j=19, h=0.80, F=0.11966
# i= 0, j=19, h=0.80, F=0.13309
# i=10, j=41, h=0.80, F=0.14348
# i=22, j=32, h=0.80, F=0.14877
# i=19, j=32, h=0.80, F=0.16233
# i=22, j= 3, h=0.80, F=0.16830
# i=24, j= 3, h=0.80, F=0.17438
# i=41, j=32, h=0.80, F=0.18052
# i=19, j=41, h=0.80, F=0.18146
# i=10, j=19, h=0.80, F=0.18271
# i=38, j=13, h=0.80, F=0.18313
# i=48, j=13, h=0.80, F=0.18328
# target elements: 42 (1.7 %)
# i=39, j=49, h=0.90, F=0.00898
# i=39, j= 4, h=0.90, F=0.04899
# i=17, j=12, h=0.90, F=0.08366
# i=31, j=12, h=0.90, F=0.13255
# i=39, j= 9, h=0.90, F=0.16229
# i= 1, j= 9, h=0.90, F=0.19474
# i= 1, j=14, h=0.90, F=0.21999
# i=40, j=14, h=0.90, F=0.24909
# i=39, j=14, h=0.90, F=0.27159
# i= 4, j=31, h=0.90, F=0.28849
# i=49, j= 9, h=0.80, F=0.30439
# ...

# %%
# %run -i plot_fig07.py
plt.show()
# Out:
# target elements: 35 (0.5 %)
# i=73, j=18, h=0.90, F=-0.96369
# i=41, j=18, h=0.90, F=-0.95859
# i=18, j=17, h=0.80, F=-0.95757
# i=76, j=22, h=0.90, F=-0.95646
# i=63, j=22, h=0.90, F=-0.95464
# i=53, j=39, h=0.90, F=-0.95321
# i= 5, j=60, h=0.90, F=-0.95148
# i=71, j=26, h=0.90, F=-0.94964
# i=76, j=26, h=0.90, F=-0.94583
# i=50, j=71, h=0.90, F=-0.94407
# i=10, j=69, h=0.90, F=-0.94315
# i=71, j=14, h=0.90, F=-0.94214
# i=69, j=14, h=0.80, F=-0.94107
# i=39, j=60, h=0.80, F=-0.93996
# i=44, j=19, h=0.90, F=-0.93949
# i=18, j=17, h=0.90, F=-0.93909
# i=50, j=71, h=0.50, F=-0.93884
# target elements: 20 (0.3 %)
# i=51, j=17, h=0.90, F=-0.97334
# i=41, j= 8, h=0.80, F=-0.97317
# i=17, j=18, h=0.80, F=-0.97314
# i=76, j=22, h=0.80, F=-0.97297
# i= 2, j=60, h=0.90, F=-0.97280
# i=71, j=26, h=0.80, F=-0.97271
# i=76, j=26, h=0.80, F=-0.97154
# i=76, j=22, h=0.90, F=-0.97152
# i=50, j=71, h=0.80, F=-0.97146
# i=76, j=26, h=0.90, F=-0.97143
# i=41, j= 8, h=0.90, F=-0.97143
# ...

# %%
# %run -i plot_fig08.py
plt.show()
# Out:
# target elements: 24 (1.0 %)
# i=45, j=46, h=0.50, F=0.14152
# i=25, j=30, h=0.50, F=0.17472
# i= 6, j= 8, h=0.50, F=0.20097
# i=23, j=24, h=0.50, F=0.21691
# i=26, j=25, h=0.50, F=0.24104
# i=44, j=47, h=0.50, F=0.25422
# i=46, j=48, h=0.50, F=0.26675
# target elements: 38 (1.5 %)
# i=17, j=14, h=0.50, F=0.76893
# i=17, j=13, h=0.50, F=0.77427
# i=18, j=15, h=0.50, F=0.77692
# i=47, j=16, h=0.50, F=0.77879
# i= 1, j= 2, h=0.50, F=0.77979
# i= 2, j= 6, h=0.50, F=0.77981
